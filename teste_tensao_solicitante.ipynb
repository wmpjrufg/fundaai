# %%
import numpy as np
import pandas as pd
from foundation import *

# %%
df = pd.read_excel('assets\\template_5_fundacoes_3_combinacoes.xlsx')


idx = 0  # índice da sapata
i = 1    # combinação de carregamento

row = df.loc[idx]

sigma_max, sigma_min = calcular_sigma_max_min(
    f_zk=row[f'Fz-c{i}'],
    m_xk=row[f'Mx-c{i}'],
    m_yk=row[f'My-c{i}'],
    h_x=0.6,
    h_y=0.6

)

print(f"σ_max = {sigma_max:.2f} kPa")
print(f"σ_min = {sigma_min:.2f} kPa")
# Out:
# σ_max = 1545.54 kPa
# σ_min = 1288.88 kPa
