# %% [markdown]
# # Bibliotecas

# %%
from fundacao import *
import pandas as pd
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Checagem das sapatas para os pilares 04, 05 e 16

# %% [markdown]
# ### Fundações que desejo empregar
#
# No formato hx_0, hy_0, hz_0 até hx_n-1, hy_n-1, hz_n-1

# %%
x = [3., 3.1, 1.0, 4.0, 3.5, 1.0, 2.7, 1.30, 1.0]
# x = [3., 3., 1., 2., 2., 1., 3., 3., 1.]

# %% [markdown]
# # Carregando dados

# %%
# df = pd.read_excel(r"/home/wmpjrufg/Documents/fundaIA/assets/toy_problem.xlsx") # Prof. Wanderlei
df = pd.read_excel(r"assets\.xlsx") # Filipe Amaral 
n_comb = 3
f_ck = 25000
cob_m = 0.04
df
# x = {'h_x (m)': 3.0, 'h_y (m)': 3.1, 'h_z (m)': 1.0}
# x = pd.DataFrame([x])
# x = [3, 3.1, 1.0, 4, 4.1, 1.2, 5, 5.1, 1.3]
# x_arr = np.asarray(x).reshape(3, 3)
# print(x, '\n', x_arr)
# df_aux_aux = pd.DataFrame(x_arr, columns=["h_x (m)", "h_y (m)", "h_z (m)"])
# print(df_aux_aux)
# Out:
#     El  ap (m)  bp (m)  spt    solo  xg (m)  yg (m)  Fz-c1  Mx-c1  My-c1  \
# 0  P01    0.25    0.15   10  argila     1.0     1.0   1000     30      2
# 1  P02    0.30    0.15   10  argila     2.0     2.0   1000     30      2
# 2  P03    0.30    0.15   10  argila     2.5     2.5   1000     30      2
#
#    Fz-c2  Mx-c2  My-c2  Fz-c3  Mx-c3  My-c3
# 0    200    -30     -1    500     -2      5
# 1    200    -30     -1    500     -2      5
# 2    200    -30     -1    500     -2      5

# %% [markdown]
# # Avaliação da FO

# %%
args = [df, n_comb, f_ck, cob_m]
of, df_res = obj_teste(x, args)
df_res
# Out:
#     El  ap (m)  bp (m)   spt    solo  xg (m)  yg (m)  Fz-c1  Mx-c1  My-c1  \
# 0  P01    0.25    0.15  10.0  argila     1.0     1.0   1000     30      2
# 1  P02    0.30    0.15  10.0  argila     2.0     2.0   1000     30      2
# 2  P03    0.30    0.15  10.0  argila     2.5     2.5   1000     30      2
#
#    Fz-c2  Mx-c2  My-c2  Fz-c3  Mx-c3  My-c3  h_x (m)  h_y (m)  h_z (m)  \
# 0    200    -30     -1    500     -2      5      3.0      3.1      1.0
# 1    200    -30     -1    500     -2      5      4.0      3.5      1.0
# 2    200    -30     -1    500     -2      5      2.7      1.3      1.0
#
#    volume (m3)    x1    y1    x2    y2    x3    y3    x4    y4  \
# 0         9.30 -0.50 -0.55  2.50 -0.55  2.50  2.55 -0.50  2.55
# 1        14.00  0.00  0.25  4.00  0.25  4.00  3.75  0.00  3.75
# 2         3.51  1.15  1.85  3.85  1.85  3.85  3.15  1.15  3.15
#
#    g sobreposicao  tensao adm. (kPa)  tau_sd2 - c1  tau_rd2 - c1  u_rd2 - c1  \
# 0        0.719892              200.0   1822.916667   4339.285714         0.8
# 1        0.661429              200.0   1620.370370   4339.285714         0.9
# 2        1.269231              200.0   1620.370370   4339.285714         0.9
#
#    g_rd2 - c1  tau_sd2 - c2  tau_rd2 - c2  u_rd2 - c2  g_rd2 - c2  \
# 0   -0.579904    364.583333   4339.285714         0.8   -0.915981
# 1   -0.626581    324.074074   4339.285714         0.9   -0.925316
# 2   -0.626581    324.074074   4339.285714         0.9   -0.925316
#
#    tau_sd2 - c3  tau_rd2 - c3  u_rd2 - c3  g_rd2 - c3  g punção secao C  \
# 0    911.458333   4339.285714         0.8   -0.789952         -0.579904
# 1    810.185185   4339.285714         0.9   -0.813291         -0.626581
# 2    810.185185   4339.285714         0.9   -0.813291         -0.626581
#
#    tensao max. (kPa) - c1  tensao min. (kPa) - c1  g tensao max. - c1  \
# 0              156.148803              137.399584           -0.219256
# 1              102.221786               92.778214           -0.488891
# 2              418.404558              359.373219            1.092023
#
#    g tensao min. - c1  g tensao - c1  tensao max. (kPa) - c2  \
# 0           -0.313002      -0.219256               38.445369
# 1           -0.536109      -0.488891               24.054643
# 2            0.796866       1.092023              105.498575
#
#    tensao min. (kPa) - c2  g tensao max. - c2  g tensao min. - c2  \
# 0               20.264308           -0.807773           -0.898678
# 1               14.945357           -0.879727           -0.925273
# 2               50.056980           -0.472507           -0.749715
#
#    g tensao - c2  tensao max. (kPa) - c3  tensao min. (kPa) - c3  \
# 0      -0.807773               75.394589               71.379605
# 1      -0.879727               49.878214               47.621786
# 2      -0.472507              205.147198              183.741690
#
#    g tensao max. - c3  g tensao min. - c3  g tensao - c3  g tensao  \
# 0           -0.623027           -0.643102      -0.623027 -0.219256
# 1           -0.750609           -0.761891      -0.750609 -0.488891
# 2            0.025736           -0.081292       0.025736  1.092023
#
#    g geometria x  g geometria y  g geometria  volume final (m3)
# 0     -10.200000     -18.333333   -10.200000          16.498925
# 1     -11.666667     -21.000000   -11.666667          20.614286
# 2      -7.333333      -6.333333    -6.333333          27.122536

# %%
df_res["volume final (m3)"].sum()
# Out:
# 64.23574605800412

# %%
of
# Out:
# 64.23574605800412

# %% [markdown]
# # Tabelas de resultados

# %%
df_res.columns
# Out:
# Index(['El', 'ap (m)', 'bp (m)', 'spt', 'solo', 'xg (m)', 'yg (m)', 'Fz-c1',
#        'Mx-c1', 'My-c1', 'Fz-c2', 'Mx-c2', 'My-c2', 'Fz-c3', 'Mx-c3', 'My-c3',
#        'h_x (m)', 'h_y (m)', 'h_z (m)', 'volume (m3)', 'x1', 'y1', 'x2', 'y2',
#        'x3', 'y3', 'x4', 'y4', 'g sobreposicao', 'tensao adm. (kPa)',
#        'tau_sd2 - c1', 'tau_rd2 - c1', 'u_rd2 - c1', 'g_rd2 - c1',
#        'tau_sd2 - c2', 'tau_rd2 - c2', 'u_rd2 - c2', 'g_rd2 - c2',
#        'tau_sd2 - c3', 'tau_rd2 - c3', 'u_rd2 - c3', 'g_rd2 - c3',
#        'g punção secao C', 'tensao max. (kPa) - c1', 'tensao min. (kPa) - c1',
#        'g tensao max. - c1', 'g tensao min. - c1', 'g tensao - c1',
#        'tensao max. (kPa) - c2', 'tensao min. (kPa) - c2',
#        'g tensao max. - c2', 'g tensao min. - c2', 'g tensao - c2',
#        'tensao max. (kPa) - c3', 'tensao min. (kPa) - c3',
#        'g tensao max. - c3', 'g tensao min. - c3', 'g tensao - c3', 'g tensao',
#        'g geometria x', 'g geometria y', 'g geometria', 'volume final (m3)'],
#       dtype='object')

# %%
df_gtensao = df_res[['tensao max. (kPa) - c1',
       'tensao min. (kPa) - c1', 'g tensao max. - c1', 'g tensao min. - c1',
       'g tensao - c1', 'tensao max. (kPa) - c2', 'tensao min. (kPa) - c2',
       'g tensao max. - c2', 'g tensao min. - c2', 'g tensao - c2',
       'tensao max. (kPa) - c3', 'tensao min. (kPa) - c3',
       'g tensao max. - c3', 'g tensao min. - c3', 'g tensao - c3', 'g tensao',]]
print(
        df_gtensao.to_latex(
                            column_format=''.join(['c' for _ in range(len(df_gtensao.columns) + 1)]),
                            float_format="%.2f",
                            caption='Resultados das tensões e verificações',
                            label='tab:tensoes_s16',
                            index=False,
                            position='htbp'
                        )
    )
# Out:
# \begin{table}[htbp]
# \caption{Resultados das tensões e verificações}
# \label{tab:tensoes_s16}
# \begin{tabular}{ccccccccccccccccc}
# \toprule
# tensao max. (kPa) - c1 & tensao min. (kPa) - c1 & g tensao max. - c1 & g tensao min. - c1 & g tensao - c1 & tensao max. (kPa) - c2 & tensao min. (kPa) - c2 & g tensao max. - c2 & g tensao min. - c2 & g tensao - c2 & tensao max. (kPa) - c3 & tensao min. (kPa) - c3 & g tensao max. - c3 & g tensao min. - c3 & g tensao - c3 & g tensao \\
# \midrule
# 156.15 & 137.40 & -0.22 & -0.31 & -0.22 & 38.45 & 20.26 & -0.81 & -0.90 & -0.81 & 75.39 & 71.38 & -0.62 & -0.64 & -0.62 & -0.22 \\
# 102.22 & 92.78 & -0.49 & -0.54 & -0.49 & 24.05 & 14.95 & -0.88 & -0.93 & -0.88 & 49.88 & 47.62 & -0.75 & -0.76 & -0.75 & -0.49 \\
# 418.40 & 359.37 & 1.09 & 0.80 & 1.09 & 105.50 & 50.06 & -0.47 & -0.75 & -0.47 & 205.15 & 183.74 & 0.03 & -0.08 & 0.03 & 1.09 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
df_gpuncao = df_res[['tau_{sd2 - c1', 'tau_rd2 - c1', 
       'g_rd2 - c1', 'tau_sd2 - c2', 'tau_rd2 - c2', 
       'g_rd2 - c2', 'tau_sd2 - c3', 'tau_rd2 - c3',
       'g_rd2 - c3', 'g punção secao C']]
print(
        df_gpuncao.to_latex(
                            column_format=''.join(['c' for _ in range(len(df_gtensao.columns) + 1)]),
                            float_format="%.2f",
                            caption='Resultados da punção',
                            label='tab:punção_s16',
                            index=False,
                            position='htbp'
                            ))
# Out:
# \begin{table}[htbp]
# \caption{Resultados das punção}
# \label{tab:tensoes_s16}
# \begin{tabular}{ccccccccccccccccc}
# \toprule
# tau_sd2 - c1 & tau_rd2 - c1 & u_rd2 - c1 & g_rd2 - c1 & tau_sd2 - c2 & tau_rd2 - c2 & u_rd2 - c2 & g_rd2 - c2 & tau_sd2 - c3 & tau_rd2 - c3 & u_rd2 - c3 & g_rd2 - c3 & g punção secao C \\
# \midrule
# 1822.92 & 4339.29 & 0.80 & -0.58 & 364.58 & 4339.29 & 0.80 & -0.92 & 911.46 & 4339.29 & 0.80 & -0.79 & -0.58 \\
# 1620.37 & 4339.29 & 0.90 & -0.63 & 324.07 & 4339.29 & 0.90 & -0.93 & 810.19 & 4339.29 & 0.90 & -0.81 & -0.63 \\
# 1620.37 & 4339.29 & 0.90 & -0.63 & 324.07 & 4339.29 & 0.90 & -0.93 & 810.19 & 4339.29 & 0.90 & -0.81 & -0.63 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
df_gpuncao = df_res[[ 'x1', 'y1', 'x2', 'y2',
       'x3', 'y3', 'x4', 'y4', 'g sobreposicao']]
print(
        df_gpuncao.to_latex(
                            column_format=''.join(['c' for _ in range(len(df_gtensao.columns) + 1)]),
                            float_format="%.2f",
                            caption='Resultados da sobreposição',
                            label='tab:sobreposição_s16',
                            index=False,
                            position='htbp'
                            ))
# Out:
# \begin{table}[htbp]
# \caption{Resultados da sobreposição}
# \label{tab:sobreposição_s16}
# \begin{tabular}{ccccccccccccccccc}
# \toprule
# x1 & y1 & x2 & y2 & x3 & y3 & x4 & y4 & g sobreposicao \\
# \midrule
# -0.50 & -0.55 & 2.50 & -0.55 & 2.50 & 2.55 & -0.50 & 2.55 & 0.72 \\
# 0.00 & 0.25 & 4.00 & 0.25 & 4.00 & 3.75 & 0.00 & 3.75 & 0.66 \\
# 1.15 & 1.85 & 3.85 & 1.85 & 3.85 & 3.15 & 1.15 & 3.15 & 1.27 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
df_gpuncao = df_res[['h_x (m)', 'h_y (m)', 'h_z (m)',
                      'ap (m)', 'bp (m)',
                     'g geometria x', 'g geometria y', 'g geometria']]
print(
        df_gpuncao.to_latex(
                            column_format=''.join(['c' for _ in range(len(df_gtensao.columns) + 1)]),
                            float_format="%.2f",
                            caption='Resultados da verificação de gometria',
                            label='tab:geometria_s16',
                            index=False,
                            position='htbp'
                            ))
# Out:
# \begin{table}[htbp]
# \caption{Resultados da verificação de gometria}
# \label{tab:geometria_s16}
# \begin{tabular}{ccccccccccccccccc}
# \toprule
# h_x (m) & h_y (m) & h_z (m) & ap (m) & bp (m) & g geometria x & g geometria y & g geometria \\
# \midrule
# 3.00 & 3.10 & 1.00 & 0.25 & 0.15 & -10.20 & -18.33 & -10.20 \\
# 4.00 & 3.50 & 1.00 & 0.30 & 0.15 & -11.67 & -21.00 & -11.67 \\
# 2.70 & 1.30 & 1.00 & 0.30 & 0.15 & -7.33 & -6.33 & -6.33 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle


def plot_elementos_fundacao(df_res, label_col="Elemento"):
    """
    Desenha os elementos de fundação no plano cartesiano
    a partir de df_res (saída do obj_teste).

    Parâmetros
    ----------
    df_res : DataFrame
        Deve conter:
        - 'xg (m)', 'yg (m)'
        - 'h_x (m)', 'h_y (m)'
    label_col : str, opcional
        Nome da coluna para identificação dos elementos
    """

    fig, ax = plt.subplots(figsize=(9, 6))
    ax.set_aspect("equal", adjustable="box")
    ax.set_xlabel("x (m)")
    ax.set_ylabel("y (m)")
    ax.grid(True, linestyle="--", alpha=0.4)

    for _, r in df_res.iterrows():
        x_inf = r["xg (m)"] - r["h_x (m)"] / 2
        y_inf = r["yg (m)"] - r["h_y (m)"] / 2

        sapata = Rectangle(
            (x_inf, y_inf),
            r["h_x (m)"],
            r["h_y (m)"],
            fill=False,
            edgecolor="black",
            linewidth=1.5,
        )

        ax.add_patch(sapata)

        if label_col in df_res.columns:
            ax.text(
                r["xg (m)"],
                r["yg (m)"],
                str(r[label_col]),
                ha="center",
                va="center",
                fontsize=11,
                weight="bold",
            )

    # limites automáticos
    margem = max(df_res["h_x (m)"].max(), df_res["h_y (m)"].max())
    ax.set_xlim(
        df_res["xg (m)"].min() - margem,
        df_res["xg (m)"].max() + margem,
    )
    ax.set_ylim(
        df_res["yg (m)"].min() - margem,
        df_res["yg (m)"].max() + margem,
    )

    return fig, ax

fig, ax = plot_elementos_fundacao(df_res)
