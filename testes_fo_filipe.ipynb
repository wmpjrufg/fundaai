# %% [markdown]
# # Bibliotecas

# %%
from fundacao import *
import pandas as pd
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Checagem das sapatas para os pilares 04, 05 e 16

# %% [markdown]
# ### Fundações que desejo empregar
#
# No formato hx_0, hy_0, hz_0 até hx_n-1, hy_n-1, hz_n-1

# %%
x = [3., 3.1, 1.0, 4.0, 3.5, 1.0, 2.7, 1.30, 1.0]
# x = [3., 3., 1., 2., 2., 1., 3., 3., 1.]

# %% [markdown]
# # Carregando dados

# %%
# df = pd.read_excel(r"/home/wmpjrufg/Documents/fundaIA/assets/toy_problem.xlsx") # Prof. Wanderlei
df = pd.read_excel(r"assets/toy_problem.xlsx") # Filipe Amaral 
n_comb = 3
f_ck = 25000
cob_m = 0.04
df
# x = {'h_x (m)': 3.0, 'h_y (m)': 3.1, 'h_z (m)': 1.0}
# x = pd.DataFrame([x])
# x = [3, 3.1, 1.0, 4, 4.1, 1.2, 5, 5.1, 1.3]
# x_arr = np.asarray(x).reshape(3, 3)
# print(x, '\n', x_arr)
# df_aux_aux = pd.DataFrame(x_arr, columns=["h_x (m)", "h_y (m)", "h_z (m)"])
# print(df_aux_aux)
# Out:
#   Elemento  ap (m)  bp (m)  spt    solo  xg (m)  yg (m)  Fz-c1  Mx-c1  My-c1  \
# 0      P16    0.25     1.2   43  argila   27.75  18.065  377.3   -1.9    4.4
# 1      P04    0.30     1.5   35  argila   24.85  25.105  855.5   -3.7    9.2
# 2      P05    0.25     1.2   45  argila   24.85  25.255  478.6   -3.1    5.0
#
#    Fz-c2  Mx-c2  My-c2  Fz-c3  Mx-c3  My-c3
# 0  259.2  -27.8    0.1  383.8   27.7    0.2
# 1  891.9  -60.0    0.6  908.5  -36.9    0.4
# 2  496.0  -27.6    0.7  508.0  -27.6    0.7

# %% [markdown]
# # Avaliação da FO

# %%
args = [df, n_comb, f_ck, cob_m]
of, df_res = obj_teste(x, args)
df_res
# Out:
#   Elemento  ap (m)  bp (m)   spt    solo  xg (m)  yg (m)  Fz-c1  Mx-c1  My-c1  \
# 0      P16    0.25     1.2  43.0  argila   27.75  18.065  377.3   -1.9    4.4
# 1      P04    0.30     1.5  35.0  argila   24.85  25.105  855.5   -3.7    9.2
# 2      P05    0.25     1.2  45.0  argila   24.85  25.255  478.6   -3.1    5.0
#
#    Fz-c2  Mx-c2  My-c2  Fz-c3  Mx-c3  My-c3  h_x (m)  h_y (m)  h_z (m)  \
# 0  259.2  -27.8    0.1  383.8   27.7    0.2      3.0      3.1      1.0
# 1  891.9  -60.0    0.6  908.5  -36.9    0.4      4.0      3.5      1.0
# 2  496.0  -27.6    0.7  508.0  -27.6    0.7      2.7      1.3      1.0
#
#    volume (m3)     x1      y1     x2      y2     x3      y3     x4      y4  \
# 0         9.30  26.25  16.515  29.25  16.515  29.25  19.615  26.25  19.615
# 1        14.00  22.85  23.355  26.85  23.355  26.85  26.855  22.85  26.855
# 2         3.51  23.50  24.605  26.20  24.605  26.20  25.905  23.50  25.905
#
#    g sobreposicao  tensao adm. (kPa)  tau_sd2 - c1  tau_rd2 - c1  u_rd2 - c1  \
# 0        0.000000              860.0    189.734195   4339.285714         2.9
# 1        0.250714              700.0    346.556713   4339.285714         3.6
# 2        1.000000              900.0    240.675287   4339.285714         2.9
#
#    g_rd2 - c1  tau_sd2 - c2  tau_rd2 - c2  u_rd2 - c2  g_rd2 - c2  \
# 0   -0.956275    130.344828   4339.285714         2.9   -0.969962
# 1   -0.920135    361.302083   4339.285714         3.6   -0.916737
# 2   -0.944536    249.425287   4339.285714         2.9   -0.942519
#
#    tau_sd2 - c3  tau_rd2 - c3  u_rd2 - c3  g_rd2 - c3  g punção secao C  \
# 0    193.002874   4339.285714         2.9   -0.955522         -0.955522
# 1    368.026620   4339.285714         3.6   -0.915187         -0.915187
# 2    255.459770   4339.285714         2.9   -0.941129         -0.941129
#
#    tensao max. (kPa) - c1  tensao min. (kPa) - c1  g tensao max. - c1  \
# 0               57.185593               53.570213           -0.933505
# 1               85.490089               81.332411           -0.877871
# 2              197.775594              174.468851           -0.780249
#
#    g tensao min. - c1  g tensao - c1  tensao max. (kPa) - c2  \
# 0           -0.937709      -0.933505               46.232924
# 1           -0.883811      -0.877871               95.835536
# 2           -0.806146      -0.780249              217.997151
#
#    tensao min. (kPa) - c2  g tensao max. - c2  g tensao min. - c2  \
# 0               29.854818           -0.946241           -0.965285
# 1               78.084964           -0.863092           -0.888450
# 2              167.780627           -0.757781           -0.813577
#
#    g tensao - c2  tensao max. (kPa) - c3  tensao min. (kPa) - c3  \
# 0      -0.946241               64.520042               48.143829
# 1      -0.863092               94.042232               83.115268
# 2      -0.757781              222.663818              172.447293
#
#    g tensao max. - c3  g tensao min. - c3  g tensao - c3  g tensao  \
# 0           -0.924977           -0.944019      -0.924977 -0.924977
# 1           -0.865654           -0.881264      -0.865654 -0.863092
# 2           -0.752596           -0.808392      -0.752596 -0.752596
#
#    g geometria x  g geometria y  g geometria  volume final (m3)
# 0     -10.200000      -1.416667    -1.416667           9.300000
# 1     -11.666667      -1.200000    -1.200000          16.507143
# 2      -9.000000       0.083333     0.083333          14.343333

# %%
df_res["volume final (m3)"].sum()
# Out:
# 40.150476190476176

# %%
of
# Out:
# 40.150476190476176

# %% [markdown]
# # Tabelas de resultados

# %%
df_res.columns
# Out:
# Index(['Elemento', 'ap (m)', 'bp (m)', 'spt', 'solo', 'xg (m)', 'yg (m)',
#        'Fz-c1', 'Mx-c1', 'My-c1', 'Fz-c2', 'Mx-c2', 'My-c2', 'Fz-c3', 'Mx-c3',
#        'My-c3', 'h_x (m)', 'h_y (m)', 'h_z (m)', 'volume (m3)', 'x1', 'y1',
#        'x2', 'y2', 'x3', 'y3', 'x4', 'y4', 'g sobreposicao',
#        'tensao adm. (kPa)', 'tau_sd2 - c1', 'tau_rd2 - c1', 'u_rd2 - c1',
#        'g_rd2 - c1', 'tau_sd2 - c2', 'tau_rd2 - c2', 'u_rd2 - c2',
#        'g_rd2 - c2', 'tau_sd2 - c3', 'tau_rd2 - c3', 'u_rd2 - c3',
#        'g_rd2 - c3', 'g punção secao C', 'tensao max. (kPa) - c1',
#        'tensao min. (kPa) - c1', 'g tensao max. - c1', 'g tensao min. - c1',
#        'g tensao - c1', 'tensao max. (kPa) - c2', 'tensao min. (kPa) - c2',
#        'g tensao max. - c2', 'g tensao min. - c2', 'g tensao - c2',
#        'tensao max. (kPa) - c3', 'tensao min. (kPa) - c3',
#        'g tensao max. - c3', 'g tensao min. - c3', 'g tensao - c3', 'g tensao',
#        'g geometria x', 'g geometria y', 'g geometria', 'volume final (m3)'],
#       dtype='object')

# %%
df_gtensao = df_res[['tensao max. (kPa) - c1',
       'tensao min. (kPa) - c1', 'g tensao max. - c1', 'g tensao min. - c1',
       'g tensao - c1', 'tensao max. (kPa) - c2', 'tensao min. (kPa) - c2',
       'g tensao max. - c2', 'g tensao min. - c2', 'g tensao - c2',
       'tensao max. (kPa) - c3', 'tensao min. (kPa) - c3',
       'g tensao max. - c3', 'g tensao min. - c3', 'g tensao - c3', 'g tensao',]]
print(
        df_gtensao.to_latex(
                            column_format=''.join(['c' for _ in range(len(df_gtensao.columns) + 1)]),
                            float_format="%.2f",
                            caption='Resultados das tensões e verificações',
                            label='tab:tensoes_s16',
                            index=False,
                            position='htbp'
                        )
    )
# Out:
# \begin{table}[htbp]
# \caption{Resultados das tensões e verificações}
# \label{tab:tensoes_s16}
# \begin{tabular}{ccccccccccccccccc}
# \toprule
# tensao max. (kPa) - c1 & tensao min. (kPa) - c1 & g tensao max. - c1 & g tensao min. - c1 & g tensao - c1 & tensao max. (kPa) - c2 & tensao min. (kPa) - c2 & g tensao max. - c2 & g tensao min. - c2 & g tensao - c2 & tensao max. (kPa) - c3 & tensao min. (kPa) - c3 & g tensao max. - c3 & g tensao min. - c3 & g tensao - c3 & g tensao \\
# \midrule
# 57.19 & 53.57 & -0.93 & -0.94 & -0.93 & 46.23 & 29.85 & -0.95 & -0.97 & -0.95 & 64.52 & 48.14 & -0.92 & -0.94 & -0.92 & -0.92 \\
# 85.49 & 81.33 & -0.88 & -0.88 & -0.88 & 95.84 & 78.08 & -0.86 & -0.89 & -0.86 & 94.04 & 83.12 & -0.87 & -0.88 & -0.87 & -0.86 \\
# 197.78 & 174.47 & -0.78 & -0.81 & -0.78 & 218.00 & 167.78 & -0.76 & -0.81 & -0.76 & 222.66 & 172.45 & -0.75 & -0.81 & -0.75 & -0.75 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
df_gpuncao = df_res[['tau_sd2 - c1', 'tau_rd2 - c1', 'u_rd2 - c1',
       'g_rd2 - c1', 'tau_sd2 - c2', 'tau_rd2 - c2', 'u_rd2 - c2',
       'g_rd2 - c2', 'tau_sd2 - c3', 'tau_rd2 - c3', 'u_rd2 - c3',
       'g_rd2 - c3', 'g punção secao C']]
print(
        df_gpuncao.to_latex(
                            column_format=''.join(['c' for _ in range(len(df_gtensao.columns) + 1)]),
                            float_format="%.2f",
                            caption='Resultados das tensões e verificações',
                            label='tab:tensoes_s16',
                            index=False,
                            position='htbp'
                            ))
# Out:
# \begin{table}[htbp]
# \caption{Resultados das tensões e verificações}
# \label{tab:tensoes_s16}
# \begin{tabular}{ccccccccccccccccc}
# \toprule
# tau_sd2 - c1 & tau_rd2 - c1 & u_rd2 - c1 & g_rd2 - c1 & tau_sd2 - c2 & tau_rd2 - c2 & u_rd2 - c2 & g_rd2 - c2 & tau_sd2 - c3 & tau_rd2 - c3 & u_rd2 - c3 & g_rd2 - c3 & g punção secao C \\
# \midrule
# 189.73 & 4339.29 & 2.90 & -0.96 & 130.34 & 4339.29 & 2.90 & -0.97 & 193.00 & 4339.29 & 2.90 & -0.96 & -0.96 \\
# 346.56 & 4339.29 & 3.60 & -0.92 & 361.30 & 4339.29 & 3.60 & -0.92 & 368.03 & 4339.29 & 3.60 & -0.92 & -0.92 \\
# 240.68 & 4339.29 & 2.90 & -0.94 & 249.43 & 4339.29 & 2.90 & -0.94 & 255.46 & 4339.29 & 2.90 & -0.94 & -0.94 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle


def plot_elementos_fundacao(df_res, label_col="Elemento"):
    """
    Desenha os elementos de fundação no plano cartesiano
    a partir de df_res (saída do obj_teste).

    Parâmetros
    ----------
    df_res : DataFrame
        Deve conter:
        - 'xg (m)', 'yg (m)'
        - 'h_x (m)', 'h_y (m)'
    label_col : str, opcional
        Nome da coluna para identificação dos elementos
    """

    fig, ax = plt.subplots(figsize=(9, 6))
    ax.set_aspect("equal", adjustable="box")
    ax.set_xlabel("x (m)")
    ax.set_ylabel("y (m)")
    ax.grid(True, linestyle="--", alpha=0.4)

    for _, r in df_res.iterrows():
        x_inf = r["xg (m)"] - r["h_x (m)"] / 2
        y_inf = r["yg (m)"] - r["h_y (m)"] / 2

        sapata = Rectangle(
            (x_inf, y_inf),
            r["h_x (m)"],
            r["h_y (m)"],
            fill=False,
            edgecolor="black",
            linewidth=1.5,
        )

        ax.add_patch(sapata)

        if label_col in df_res.columns:
            ax.text(
                r["xg (m)"],
                r["yg (m)"],
                str(r[label_col]),
                ha="center",
                va="center",
                fontsize=9,
                weight="bold",
            )

    # limites automáticos
    margem = max(df_res["h_x (m)"].max(), df_res["h_y (m)"].max())
    ax.set_xlim(
        df_res["xg (m)"].min() - margem,
        df_res["xg (m)"].max() + margem,
    )
    ax.set_ylim(
        df_res["yg (m)"].min() - margem,
        df_res["yg (m)"].max() + margem,
    )

    return fig, ax

fig, ax = plot_elementos_fundacao(df_res)
