# %% [markdown]
# # Bibliotecas

# %%
from fundacao import *
import pandas as pd
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Checagem das sapatas para os pilares 04, 05 e 16

# %% [markdown]
# ### Fundações que desejo empregar
#
# No formato hx_0, hy_0, hz_0 até hx_n-1, hy_n-1, hz_n-1

# %%
# x = [3., 3.1, 1.0, 4.0, 3.5, 1.0, 2.7, 1.30, 1.0]
# x = [3., 3., 1., 2., 2., 1., 3., 3., 1.]
x = [1.204390756,	6.049401777,	0.6, 2.343794046,	2.19736651,	1.350068468, 4.60765518,	1.618718468,	0.6] #dados valores padrao
x = [2.73, 2.395, 0.605]

# %% [markdown]
# # Carregando dados

# %%
# df = pd.read_excel(r"/home/wmpjrufg/Documents/fundaIA/assets/toy_problem.xlsx") # Prof. Wanderlei
# df = pd.read_excel(r"assets\valores_padrao.xlsx") # Filipe Amaral 
df = pd.read_excel(r"assets\el08.xlsx") # Filipe Amaral 
n_comb = 3
f_ck = 25000
cob_m = 0.04
df
# x = {'h_x (m)': 3.0, 'h_y (m)': 3.1, 'h_z (m)': 1.0}
# x = pd.DataFrame([x])
# x = [3, 3.1, 1.0, 4, 4.1, 1.2, 5, 5.1, 1.3]
# x_arr = np.asarray(x).reshape(3, 3)
# print(x, '\n', x_arr)
# df_aux_aux = pd.DataFrame(x_arr, columns=["h_x (m)", "h_y (m)", "h_z (m)"])
# print(df_aux_aux)
# Out:
#   Elemento  ap (m)  bp (m)  spt    solo  xg (m)  yg (m)  Fz-c1  Mx-c1  My-c1  \
# 0      P08     2.1    0.25   12  argila   8.125   19.59  857.4   -0.2  115.6
#
#    Fz-c2  Mx-c2  My-c2  Fz-c3  Mx-c3  My-c3
# 0    913   -0.9    0.1  950.6   -0.9   -0.5

# %% [markdown]
# # Avaliação da FO

# %%
args = [df, n_comb, f_ck, cob_m]
of, df_res = obj_teste(x, args)
df_res
# Out:
#   Elemento  ap (m)  bp (m)   spt    solo  xg (m)  yg (m)  Fz-c1  Mx-c1  My-c1  \
# 0      P08     2.1    0.25  12.0  argila   8.125   19.59  857.4   -0.2  115.6
#
#    Fz-c2  Mx-c2  My-c2  Fz-c3  Mx-c3  My-c3  h_x (m)  h_y (m)  h_z (m)  \
# 0    913   -0.9    0.1  950.6   -0.9   -0.5     2.73    2.395    0.605
#
#    volume (m3)    x1       y1    x2       y2    x3       y3    x4       y4  \
# 0     3.955702  6.76  18.3925  9.49  18.3925  9.49  20.7875  6.76  20.7875
#
#    g sobreposicao  tensao adm. (kPa)  tau_sd2 - c1  tau_rd2 - c1  u_rd2 - c1  \
# 0             0.0              240.0    452.027867   4339.285714         4.7
#
#    g_rd2 - c1  tau_sd2 - c2  tau_rd2 - c2  u_rd2 - c2  g_rd2 - c2  \
# 0   -0.895829    481.340614   4339.285714         4.7   -0.889074
#
#    tau_sd2 - c3  tau_rd2 - c3  u_rd2 - c3  g_rd2 - c3  g punção secao C  \
# 0    501.163623   4339.285714         4.7   -0.884506         -0.884506
#
#    tensao max. (kPa) - c1  tensao min. (kPa) - c1  g tensao max. - c1  \
# 0              239.549666              118.446159           -0.001876
#
#    g tensao min. - c1  g tensao - c1  tensao max. (kPa) - c2  \
# 0           -0.506474      -0.001876              191.070677
#
#    tensao min. (kPa) - c2  g tensao max. - c2  g tensao min. - c2  \
# 0              190.140179           -0.203872           -0.207749
#
#    g tensao - c2  tensao max. (kPa) - c3  tensao min. (kPa) - c3  \
# 0      -0.203872              199.129568              197.780661
#
#    g tensao max. - c3  g tensao min. - c3  g tensao - c3  g tensao  \
# 0           -0.170293           -0.175914      -0.170293 -0.001876
#
#    g geometria x  g geometria y  g geometria  volume final (m3)
# 0      -0.204762          -7.78    -0.204762           3.955702

# %%
df_res["volume final (m3)"].sum()
# Out:
# 3.9557017500000002

# %%
of
# Out:
# 3.9557017500000002

# %% [markdown]
# # Tabelas de resultados

# %%
df_res.columns
# Out:
# Index(['Elemento', 'ap (m)', 'bp (m)', 'spt', 'solo', 'xg (m)', 'yg (m)',
#        'Fz-c1', 'Mx-c1', 'My-c1', 'Fz-c2', 'Mx-c2', 'My-c2', 'Fz-c3', 'Mx-c3',
#        'My-c3', 'h_x (m)', 'h_y (m)', 'h_z (m)', 'volume (m3)', 'x1', 'y1',
#        'x2', 'y2', 'x3', 'y3', 'x4', 'y4', 'g sobreposicao',
#        'tensao adm. (kPa)', 'tau_sd2 - c1', 'tau_rd2 - c1', 'u_rd2 - c1',
#        'g_rd2 - c1', 'tau_sd2 - c2', 'tau_rd2 - c2', 'u_rd2 - c2',
#        'g_rd2 - c2', 'tau_sd2 - c3', 'tau_rd2 - c3', 'u_rd2 - c3',
#        'g_rd2 - c3', 'g punção secao C', 'tensao max. (kPa) - c1',
#        'tensao min. (kPa) - c1', 'g tensao max. - c1', 'g tensao min. - c1',
#        'g tensao - c1', 'tensao max. (kPa) - c2', 'tensao min. (kPa) - c2',
#        'g tensao max. - c2', 'g tensao min. - c2', 'g tensao - c2',
#        'tensao max. (kPa) - c3', 'tensao min. (kPa) - c3',
#        'g tensao max. - c3', 'g tensao min. - c3', 'g tensao - c3', 'g tensao',
#        'g geometria x', 'g geometria y', 'g geometria', 'volume final (m3)'],
#       dtype='object')

# %%
df_gtensao = df_res[['tensao max. (kPa) - c1',
       'tensao min. (kPa) - c1', 'g tensao max. - c1', 'g tensao min. - c1',
       'g tensao - c1', 'tensao max. (kPa) - c2', 'tensao min. (kPa) - c2',
       'g tensao max. - c2', 'g tensao min. - c2', 'g tensao - c2',
       'tensao max. (kPa) - c3', 'tensao min. (kPa) - c3',
       'g tensao max. - c3', 'g tensao min. - c3', 'g tensao - c3', 'g tensao',]]
print(
        df_gtensao.to_latex(
                            column_format=''.join(['c' for _ in range(len(df_gtensao.columns) + 1)]),
                            float_format="%.2f",
                            caption='Resultados das tensões e verificações',
                            label='tab:tensoes_s16',
                            index=False,
                            position='htbp'
                        )
    )
# Out:
# \begin{table}[htbp]
# \caption{Resultados das tensões e verificações}
# \label{tab:tensoes_s16}
# \begin{tabular}{ccccccccccccccccc}
# \toprule
# tensao max. (kPa) - c1 & tensao min. (kPa) - c1 & g tensao max. - c1 & g tensao min. - c1 & g tensao - c1 & tensao max. (kPa) - c2 & tensao min. (kPa) - c2 & g tensao max. - c2 & g tensao min. - c2 & g tensao - c2 & tensao max. (kPa) - c3 & tensao min. (kPa) - c3 & g tensao max. - c3 & g tensao min. - c3 & g tensao - c3 & g tensao \\
# \midrule
# 239.55 & 118.45 & -0.00 & -0.51 & -0.00 & 191.07 & 190.14 & -0.20 & -0.21 & -0.20 & 199.13 & 197.78 & -0.17 & -0.18 & -0.17 & -0.00 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
df_gpuncao = df_res[['tau_sd2 - c1', 'tau_rd2 - c1', 
       'g_rd2 - c1', 'tau_sd2 - c2', 'tau_rd2 - c2', 
       'g_rd2 - c2', 'tau_sd2 - c3', 'tau_rd2 - c3',
       'g_rd2 - c3', 'g punção secao C']]
print(
        df_gpuncao.to_latex(
                            column_format=''.join(['c' for _ in range(len(df_gtensao.columns) + 1)]),
                            float_format="%.2f",
                            caption='Resultados da punção',
                            label='tab:punção_s16',
                            index=False,
                            position='H'
                            ))
# Out:
# \begin{table}[H]
# \caption{Resultados da punção}
# \label{tab:punção_s16}
# \begin{tabular}{ccccccccccccccccc}
# \toprule
# tau_sd2 - c1 & tau_rd2 - c1 & g_rd2 - c1 & tau_sd2 - c2 & tau_rd2 - c2 & g_rd2 - c2 & tau_sd2 - c3 & tau_rd2 - c3 & g_rd2 - c3 & g punção secao C \\
# \midrule
# 452.03 & 4339.29 & -0.90 & 481.34 & 4339.29 & -0.89 & 501.16 & 4339.29 & -0.88 & -0.88 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
df_gpuncao = df_res[[ 'x1', 'y1', 'x2', 'y2',
       'x3', 'y3', 'x4', 'y4', 'g sobreposicao']]
print(
        df_gpuncao.to_latex(
                            column_format=''.join(['c' for _ in range(len(df_gtensao.columns) + 1)]),
                            float_format="%.2f",
                            caption='Resultados da sobreposição',
                            label='tab:sobreposição_s16',
                            index=False,
                            position='htbp'
                            ))
# Out:
# \begin{table}[htbp]
# \caption{Resultados da sobreposição}
# \label{tab:sobreposição_s16}
# \begin{tabular}{ccccccccccccccccc}
# \toprule
# x1 & y1 & x2 & y2 & x3 & y3 & x4 & y4 & g sobreposicao \\
# \midrule
# 6.76 & 18.39 & 9.49 & 18.39 & 9.49 & 20.79 & 6.76 & 20.79 & 0.00 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
df_gpuncao = df_res[['h_x (m)', 'h_y (m)', 'h_z (m)',
                      'ap (m)', 'bp (m)',
                     'g geometria x', 'g geometria y', 'g geometria']]
print(
        df_gpuncao.to_latex(
                            column_format=''.join(['c' for _ in range(len(df_gtensao.columns) + 1)]),
                            float_format="%.2f",
                            caption='Resultados da verificação de gometria',
                            label='tab:geometria_s16',
                            index=False,
                            position='htbp'
                            ))
# Out:
# \begin{table}[htbp]
# \caption{Resultados da verificação de gometria}
# \label{tab:geometria_s16}
# \begin{tabular}{ccccccccccccccccc}
# \toprule
# h_x (m) & h_y (m) & h_z (m) & ap (m) & bp (m) & g geometria x & g geometria y & g geometria \\
# \midrule
# 2.73 & 2.40 & 0.60 & 2.10 & 0.25 & -0.20 & -7.78 & -0.20 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle


def plot_elementos_fundacao(df_res, label_col="Elemento"):
    """
    Desenha os elementos de fundação no plano cartesiano
    a partir de df_res (saída do obj_teste).

    Parâmetros
    ----------
    df_res : DataFrame
        Deve conter:
        - 'xg (m)', 'yg (m)'
        - 'h_x (m)', 'h_y (m)'
    label_col : str, opcional
        Nome da coluna para identificação dos elementos
    """

    fig, ax = plt.subplots(figsize=(9, 6))
    ax.set_aspect("equal", adjustable="box")
    ax.set_xlabel("x (m)")
    ax.set_ylabel("y (m)")
    ax.grid(True, linestyle="--", alpha=0.4)

    for _, r in df_res.iterrows():
        x_inf = r["xg (m)"] - r["h_x (m)"] / 2
        y_inf = r["yg (m)"] - r["h_y (m)"] / 2

        sapata = Rectangle(
            (x_inf, y_inf),
            r["h_x (m)"],
            r["h_y (m)"],
            fill=False,
            edgecolor="black",
            linewidth=1.5,
        )

        ax.add_patch(sapata)

        if label_col in df_res.columns:
            ax.text(
                r["xg (m)"],
                r["yg (m)"],
                str(r[label_col]),
                ha="center",
                va="center",
                fontsize=11,
                weight="bold",
            )

    # limites automáticos
    margem = max(df_res["h_x (m)"].max(), df_res["h_y (m)"].max())
    ax.set_xlim(
        df_res["xg (m)"].min() - margem,
        df_res["xg (m)"].max() + margem,
    )
    ax.set_ylim(
        df_res["yg (m)"].min() - margem,
        df_res["yg (m)"].max() + margem,
    )

    return fig, ax

fig, ax = plot_elementos_fundacao(df_res)
