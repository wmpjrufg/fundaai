# %%
import numpy as np
import pandas as pd
from foundation import *

# %%
df = pd.read_excel('assets\dados_exercício_4_paulo_bastos.xlsx')


idx = 0  # índice da sapata
i = 1    # combinação de carregamento

row = df.loc[idx]

df[['sigma max. (kPa)', 'sigma min. (kPa)']] = df.apply(
    lambda row: calcular_sigma_max_min(
        f_zk=row[f'Fz-c{i}'],
        m_xk=row[f'Mx-c{i}'],
        m_yk=row[f'My-c{i}'],
        h_x=2.2, #dados do problema 4 da apostila paulo de bastos
        h_y=2.0 #dados do problema 4 da apostila paulo de bastos
    ),
    axis=1,
    result_type='expand'
)

df
# Out:
#   Elemento  ap (m)  bp (m)  spt    solo  xg (m)  yg (m)  Fz-c1  Mx-c1  My-c1  \
# 0      P01     0.6     0.4   25  argila       0       0   1140    280    190
#
#    Fz-c2  Mx-c2  My-c2  Fz-c3  Mx-c3  My-c3  sigma max. (kPa)  \
# 0    NaN    NaN    NaN    NaN    NaN    NaN        590.299587
#
#    sigma min. (kPa)
# 0        -46.208678
