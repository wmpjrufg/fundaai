# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

from foundation import *

# %% [markdown]
# # Obj test

# %%
df = pd.read_excel("assets\dados_exercício_4_paulo_bastos.xlsx") # Prof. Wanderlei
n_comb = 1
f_ck = 25000
h_z = 1

# %%
df
# Out:
#   Elemento  ap (m)  bp (m)  spt    solo  xg (m)  yg (m)  Fz-c1  Mx-c1  My-c1  \
# 0      P01     0.6     0.4   25  argila       0       0   1140    280    190
#
#    Fz-c2  Mx-c2  My-c2  Fz-c3  Mx-c3  My-c3
# 0    NaN    NaN    NaN    NaN    NaN    NaN

# %%
fun = [4.961042707106475, 1.5081328164308174]
of, df_novo = obj_teste(fun, args=(df, n_comb, f_ck, h_z))
of
# Out:
# 7.4819113103020545

# %%
fun = [4.091003961,
        3.802109717,
        3.518412548,
        0.900834476,
        1.511661137,
        2.831424183,
        3.969535234,
        2.767383867,
        4.538378605,
        1.87203888,
]
h_z = 0.6
f_ck = 25000
a_p = 0.20
b_p = 0.6
f_zk = 20000
m_xk = 10000
m_yk = 15000
sigma_cp = 1500000
cob = 0.02

tau_sd2, tau_rd2, u_rd2, g_rd2, k_e, g_ed, tau_rd1, u_rd1, kx, ky, w_px, w_py, tau_sd1, g_rd1 = obj_teste_puncao(fun, args=(h_z, f_ck, a_p, b_p, f_zk, m_xk, m_yk, sigma_cp, cob))


print(g_rd2, g_rd1, g_ed)
print(tau_sd2, tau_rd2, u_rd2, k_e )
print(tau_rd1, u_rd1, kx, ky)
print(w_px, w_py, tau_sd1 )

print("\n=== RESULTADOS – VERIFICAÇÃO À PUNÇÃO ===\n")

print(f"tau_sd2 (kPa) : {tau_sd2:.4f}")
print(f"tau_rd2 (kPa) : {tau_rd2:.4f}")
print(f"u_rd2 (m)     : {u_rd2:.4f}")
print(f"g_rd2 (-)     : {g_rd2:.4f}")

print(f"k_e (-)       : {k_e:.4f}")
print(f"g_ed (-)      : {g_ed:.4f}")

print(f"tau_sd1 (kPa) : {tau_sd1:.4f}")
print(f"tau_rd1 (kPa) : {tau_rd1:.4f}")
print(f"u_rd1 (m)     : {u_rd1:.4f}")
print(f"g_rd1 (-)     : {g_rd1:.4f}")

print(f"kx (-)        : {kx:.4f}")
print(f"ky (-)        : {ky:.4f}")
print(f"w_px (m³)     : {w_px:.4f}")
print(f"w_py (m³)     : {w_py:.4f}")

# %%
df_novo
# Out:
#   Elemento  ap (m)  bp (m)  spt    solo  xg (m)  yg (m)  Fz-c1  Mx-c1  My-c1  \
# 0      P01     0.6     0.4   25  argila       0       0   1140    280    190
#
#    Fz-c2  Mx-c2  My-c2  Fz-c3  Mx-c3  My-c3   h_x (m)   h_y (m)  h_z (m)  \
# 0    NaN    NaN    NaN    NaN    NaN    NaN  4.961043  1.508133        1
#
#    volume (m3)        x1        y1        x2        y2        x3        y3  \
# 0     7.481911 -2.480521 -0.754066  2.480521 -0.754066  2.480521  0.754066
#
#          x4        y4  g sobreposicao  tensao adm. (kPa)  tau_sd2 - c1  \
# 0 -2.480521  0.754066             0.0              500.0    818.461538
#
#    tau_rd2 - c1  u_rd2 - c1  g_rd2 - c1  k_e - c1  g_ed - c1  tau_rd1 - c1  \
# 0   4339.285714         2.0   -0.811383  1.452911  -0.273545    293.444561
#
#    u_rd1 - c1  kx - c1  ky - c1  w_px - c1  w_py - c1  tau_sd1 - c1  \
# 0    8.283185     0.65      0.5   7.104956   6.776637     254.53133
#
#    g_rd1 - c1  g punção secao C  g escala punção  g punção secao Clinha  \
# 0   -0.132608         -0.811383        -0.273545              -0.132608
#
#    tensao max. (kPa) - c1  tensao min. (kPa) - c1  g tensao max. - c1  \
# 0               313.59194                6.379775           -0.184661
#
#    g tensao min. - c1  g tensao - c1  g tensao  g geometria x  g geometria y  \
# 0           -0.983413      -0.184661 -0.184661      -4.461043      -1.208133
#
#    g geometria  volume final (m3)
# 0    -1.208133           7.481911
