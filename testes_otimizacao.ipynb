# %% [markdown]
# # Libraries

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

from foundation import *

# %% [markdown]
# # Obj test

# %%
df = pd.read_excel("assets/template_5_fundacoes_3_combinacoes.xlsx") # Prof. Wanderlei
n_comb = 3

# %%
df
# Out:
#   Elemento  ap (m)  bp (m)  spt    solo  xg (m)  yg (m)   Fz-c1  Mx-c1  My-c1  \
# 0      P01    0.25    1.20   10  argila   2.900  25.255   485.9   -0.3    4.1
# 1      P02    0.30    1.50   12  argila   7.985  25.105   885.8   -1.0    9.2
# 2      P03    0.35    2.32   30  argila  13.875  25.515  1314.0   -3.9   20.4
# 3      P04    0.30    1.50   35  argila  24.850  25.105   855.5   -3.7    9.2
# 4      P05    0.25    1.20   45  argila  24.850  25.255   478.6   -3.1    5.0
#
#     Fz-c2  Mx-c2  My-c2   Fz-c3  Mx-c3  My-c3
# 0   511.6  -32.4   -0.4   511.6  -32.4   -0.4
# 1   912.1  -65.4    0.1   915.9  -40.0    0.1
# 2  1696.4 -214.1    0.8  1698.9 -214.6    0.7
# 3   891.9  -60.0    0.6   908.5  -36.9    0.4
# 4   496.0  -27.6    0.7   508.0  -27.6    0.7

# %%
fun = [3.691969948042901, 1.5442743045121943]
of, df_novo = obj_teste(fun, args=(df, n_comb))
of
# Out:
# 17.10424297138162

# %%
df_novo
# Out:
#   Elemento  ap (m)  bp (m)  spt    solo  xg (m)  yg (m)   Fz-c1  Mx-c1  My-c1  \
# 0      P01    0.25    1.20   10  argila   2.900  25.255   485.9   -0.3    4.1
# 1      P02    0.30    1.50   12  argila   7.985  25.105   885.8   -1.0    9.2
# 2      P03    0.35    2.32   30  argila  13.875  25.515  1314.0   -3.9   20.4
# 3      P04    0.30    1.50   35  argila  24.850  25.105   855.5   -3.7    9.2
# 4      P05    0.25    1.20   45  argila  24.850  25.255   478.6   -3.1    5.0
#
#     Fz-c2  Mx-c2  My-c2   Fz-c3  Mx-c3  My-c3  h_x (m)   h_y (m)  h_z (m)  \
# 0   511.6  -32.4   -0.4   511.6  -32.4   -0.4  3.69197  1.544274      0.6
# 1   912.1  -65.4    0.1   915.9  -40.0    0.1  3.69197  1.544274      0.6
# 2  1696.4 -214.1    0.8  1698.9 -214.6    0.7  3.69197  1.544274      0.6
# 3   891.9  -60.0    0.6   908.5  -36.9    0.4  3.69197  1.544274      0.6
# 4   496.0  -27.6    0.7   508.0  -27.6    0.7  3.69197  1.544274      0.6
#
#    volume (m3)  tensao adm. (kPa)  tensao max. (kPa) - c1  \
# 0     3.420849              200.0               88.103991
# 1     3.420849              240.0              161.919489
# 2     3.420849              600.0              245.482705
# 3     3.420849              700.0              157.374634
# 4     3.420849              900.0               88.235047
#
#    tensao min. (kPa) - c1  g tensao max. - c1  g tensao min. - c1  \
# 0               82.344944           -0.427324           -0.464758
# 1              148.810428           -0.122936           -0.193944
# 2              215.455555           -0.468121           -0.533180
# 3              142.726341           -0.707733           -0.734937
# 4               79.653120           -0.872549           -0.884945
#
#    g tensao - c1  tensao max. (kPa) - c2  tensao min. (kPa) - c2  \
# 0      -0.427324               99.240103               80.224139
# 1      -0.122936              178.687813              141.267885
# 2      -0.468121              359.113102              235.967313
# 3      -0.707733              173.946332              138.923405
# 4      -0.872549               95.340173               78.651743
#
#    g tensao max. - c2  g tensao min. - c2  g tensao - c2  \
# 0           -0.354939           -0.478543      -0.354939
# 1           -0.032108           -0.234799      -0.032108
# 2           -0.221922           -0.488737      -0.221922
# 3           -0.676957           -0.741999      -0.676957
# 4           -0.862286           -0.886392      -0.862286
#
#    tensao max. (kPa) - c3  tensao min. (kPa) - c3  g tensao max. - c3  \
# 0               99.240103               80.224139           -0.354939
# 1              172.114220              149.174481           -0.067715
# 2              359.625965              236.331425           -0.220810
# 3              170.137103              148.555751           -0.684031
# 4               97.444914               80.756484           -0.859246
#
#    g tensao min. - c3  g tensao - c3  g tensao  volume final (m3)
# 0           -0.478543      -0.354939 -0.354939           3.420849
# 1           -0.191972      -0.067715 -0.032108           3.420849
# 2           -0.487949      -0.220810 -0.220810           3.420849
# 3           -0.724111      -0.684031 -0.676957           3.420849
# 4           -0.883352      -0.859246 -0.859246           3.420849
