# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

from foundation import *

# %% [markdown]
# # Obj test

# %%
df = pd.read_excel(r"assets/template_5_fundacoes_3_combinacoes_espalhadas.xlsx") # Prof. Wanderlei
n_comb = 3
f_ck = 25000
h_z = 0.60

# %%
df
# Out:
#   Elemento  ap (m)  bp (m)  spt    solo  xg (m)  yg (m)   Fz-c1  Mx-c1  My-c1  \
# 0      P01    0.25    1.20   10  argila    2.90   25.26   485.9   -0.3    4.1
# 1      P07    0.25    1.75   50  argila   27.75   24.98   380.8   -6.1    6.2
# 2      P13    0.30    2.20   23  argila   13.88   18.57  1071.0   -1.4    4.2
# 3      P27    1.20    0.25   76  argila    5.21    7.12   350.8   -0.6    0.4
# 4      P39    0.30    1.50   34  argila   19.77   -0.40   870.9    2.9    8.9
#
#     Fz-c2  Mx-c2  My-c2   Fz-c3  Mx-c3  My-c3
# 0   511.6  -32.4   -0.4   511.6  -32.4   -0.4
# 1   402.4  -70.0    0.5   402.4  -70.0    0.5
# 2  1102.5   72.3    0.1  1144.1   72.1    0.1
# 3   350.8   -0.6    0.4   370.2   -0.6    0.4
# 4   861.3  -75.1    0.4   928.2   76.5   -0.2

# %%
x_aux = pd.read_excel("geometria_da_sapata (3).xlsx")
x_aux.head()
# Out:
#     h_x (m)   h_y (m)  h_z (m)
# 0  2.633597  2.659562      0.6
# 1  1.929113  4.991604      0.6
# 2  2.126807  4.941829      0.6
# 3  3.256025  0.995228      0.6
# 4  3.999989  3.834513      0.6

# %%
x = list(x_aux['h_x (m)']) + list(x_aux['h_y (m)'])
h_z = x_aux['h_z (m)'].values[0]
h_z
# Out:
# 0.6

# %%
of, df_novo = obj_teste(x, args=(df, n_comb, f_ck, h_z))
df_novo
# Out:
#   Elemento  ap (m)  bp (m)  spt    solo  xg (m)  yg (m)   Fz-c1  Mx-c1  My-c1  \
# 0      P01    0.25    1.20   10  argila    2.90   25.26   485.9   -0.3    4.1
# 1      P07    0.25    1.75   50  argila   27.75   24.98   380.8   -6.1    6.2
# 2      P13    0.30    2.20   23  argila   13.88   18.57  1071.0   -1.4    4.2
# 3      P27    1.20    0.25   76  argila    5.21    7.12   350.8   -0.6    0.4
# 4      P39    0.30    1.50   34  argila   19.77   -0.40   870.9    2.9    8.9
#
#     Fz-c2  Mx-c2  My-c2   Fz-c3  Mx-c3  My-c3   h_x (m)   h_y (m)  h_z (m)  \
# 0   511.6  -32.4   -0.4   511.6  -32.4   -0.4  2.633597  1.929113      0.6
# 1   402.4  -70.0    0.5   402.4  -70.0    0.5  2.126807  3.256025      0.6
# 2  1102.5   72.3    0.1  1144.1   72.1    0.1  3.999989  2.659562      0.6
# 3   350.8   -0.6    0.4   370.2   -0.6    0.4  4.991604  4.941829      0.6
# 4   861.3  -75.1    0.4   928.2   76.5   -0.2  0.995228  3.834513      0.6
#
# ...

# %%
of
# Out:
# 50874.38018206818

# %%
# fun = [4.091003961,
#         3.802109717,
#         3.518412548,
#         0.900834476,
#         1.511661137,
#         2.831424183,
#         3.969535234,
#         2.767383867,
#         4.538378605,
#         1.87203888,
# ]
# h_z = 0.6
# f_ck = 25000
# a_p = 0.20
# b_p = 0.6
# f_zk = 20000
# m_xk = 10000
# m_yk = 15000
# sigma_cp = 1500000
# cob = 0.02

# tau_sd2, tau_rd2, u_rd2, g_rd2, k_e, g_ed, tau_rd1, u_rd1, kx, ky, w_px, w_py, tau_sd1, g_rd1 = obj_teste_puncao(fun, args=(h_z, f_ck, a_p, b_p, f_zk, m_xk, m_yk, sigma_cp, cob))


# print(g_rd2, g_rd1, g_ed)
# print(tau_sd2, tau_rd2, u_rd2, k_e )
# print(tau_rd1, u_rd1, kx, ky)
# print(w_px, w_py, tau_sd1 )

# print("\n=== RESULTADOS – VERIFICAÇÃO À PUNÇÃO ===\n")

# print(f"tau_sd2 (kPa) : {tau_sd2:.4f}")
# print(f"tau_rd2 (kPa) : {tau_rd2:.4f}")
# print(f"u_rd2 (m)     : {u_rd2:.4f}")
# print(f"g_rd2 (-)     : {g_rd2:.4f}")

# print(f"k_e (-)       : {k_e:.4f}")
# print(f"g_ed (-)      : {g_ed:.4f}")

# print(f"tau_sd1 (kPa) : {tau_sd1:.4f}")
# print(f"tau_rd1 (kPa) : {tau_rd1:.4f}")
# print(f"u_rd1 (m)     : {u_rd1:.4f}")
# print(f"g_rd1 (-)     : {g_rd1:.4f}")

# print(f"kx (-)        : {kx:.4f}")
# print(f"ky (-)        : {ky:.4f}")
# print(f"w_px (m³)     : {w_px:.4f}")
# print(f"w_py (m³)     : {w_py:.4f}")
