# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

from foundation import *

# %% [markdown]
# # Obj test

# %%
df = pd.read_excel("assets/template_5_fundacoes_3_combinacoes.xlsx") # Prof. Wanderlei
n_comb = 3
f_ck = 25000
h_z = 0.60

# %%
df
# Out:
#   Elemento  ap (m)  bp (m)  spt    solo  xg (m)  yg (m)   Fz-c1  Mx-c1  My-c1  \
# 0      P01    0.25    1.20   10  argila   2.900  25.255   485.9   -0.3    4.1
# 1      P02    0.30    1.50   12  argila   7.985  25.105   885.8   -1.0    9.2
# 2      P03    0.35    2.32   30  argila  13.875  25.515  1314.0   -3.9   20.4
# 3      P04    0.30    1.50   35  argila  24.850  25.105   855.5   -3.7    9.2
# 4      P05    0.25    1.20   45  argila  24.850  25.255   478.6   -3.1    5.0
#
#     Fz-c2  Mx-c2  My-c2   Fz-c3  Mx-c3  My-c3
# 0   511.6  -32.4   -0.4   511.6  -32.4   -0.4
# 1   912.1  -65.4    0.1   915.9  -40.0    0.1
# 2  1696.4 -214.1    0.8  1698.9 -214.6    0.7
# 3   891.9  -60.0    0.6   908.5  -36.9    0.4
# 4   496.0  -27.6    0.7   508.0  -27.6    0.7

# %%
fun = [4.091003961,
        3.802109717,
        3.518412548,
        0.900834476,
        1.511661137,
        2.831424183,
        3.969535234,
        2.767383867,
        4.538378605,
        1.87203888,
]
of, df_novo = obj_teste(fun, args=(df, n_comb, f_ck, h_z))
of
# Out:
# 5676854049.4769745

# %%
fun = [4.091003961,
        3.802109717,
        3.518412548,
        0.900834476,
        1.511661137,
        2.831424183,
        3.969535234,
        2.767383867,
        4.538378605,
        1.87203888,
]
h_z = 0.6
f_ck = 25000
a_p = 0.20
b_p = 0.6
f_zk = 20000
m_xk = 10000
m_yk = 15000
sigma_cp = 1500000
cob = 0.02

tau_sd2, tau_rd2, u_rd2, g_rd2, k_e, g_ed, tau_rd1, u_rd1, kx, ky, w_px, w_py, tau_sd1, g_rd1 = obj_teste_puncao(fun, args=(h_z, f_ck, a_p, b_p, f_zk, m_xk, m_yk, sigma_cp, cob))


print(g_rd2, g_rd1, g_ed)
print(tau_sd2, tau_rd2, u_rd2, k_e )
print(tau_rd1, u_rd1, kx, ky)
print(w_px, w_py, tau_sd1 )

print("\n=== RESULTADOS – VERIFICAÇÃO À PUNÇÃO ===\n")

print(f"tau_sd2 (kPa) : {tau_sd2:.4f}")
print(f"tau_rd2 (kPa) : {tau_rd2:.4f}")
print(f"u_rd2 (m)     : {u_rd2:.4f}")
print(f"g_rd2 (-)     : {g_rd2:.4f}")

print(f"k_e (-)       : {k_e:.4f}")
print(f"g_ed (-)      : {g_ed:.4f}")

print(f"tau_sd1 (kPa) : {tau_sd1:.4f}")
print(f"tau_rd1 (kPa) : {tau_rd1:.4f}")
print(f"u_rd1 (m)     : {u_rd1:.4f}")
print(f"g_rd1 (-)     : {g_rd1:.4f}")

print(f"kx (-)        : {kx:.4f}")
print(f"ky (-)        : {ky:.4f}")
print(f"w_px (m³)     : {w_px:.4f}")
print(f"w_py (m³)     : {w_py:.4f}")
# Out:
# -1.000002688615616 nan nan
# -0.0116666713333352 4339.285714285715 1.6 nan
# nan 3.484955592153876 0.45 0.8
# 2.676991118430775 3.1109733552923258 -0.010525446369740597
#
# === RESULTADOS – VERIFICAÇÃO À PUNÇÃO ===
#
# tau_sd2 (kPa) : -0.0117
# tau_rd2 (kPa) : 4339.2857
# u_rd2 (m)     : 1.6000
# g_rd2 (-)     : -1.0000
# k_e (-)       : nan
# g_ed (-)      : nan
# tau_sd1 (kPa) : -0.0105
# tau_rd1 (kPa) : nan
# u_rd1 (m)     : 3.4850
# g_rd1 (-)     : nan
# kx (-)        : 0.4500
# ky (-)        : 0.8000
# w_px (m³)     : 2.6770
# w_py (m³)     : 3.1110
# c:\Users\epili\Documents\GitHub\fundaIA\foundation.py:168: RuntimeWarning: invalid value encountered in sqrt
#   k_e = min(1 + np.sqrt(20 / (d * 100)), 2.0)

# %%
df_novo
# Out:
#   Elemento  ap (m)  bp (m)  spt    solo  xg (m)  yg (m)   Fz-c1  Mx-c1  My-c1  \
# 0      P01    0.25    1.20   10  argila   2.900  25.255   485.9   -0.3    4.1
# 1      P02    0.30    1.50   12  argila   7.985  25.105   885.8   -1.0    9.2
# 2      P03    0.35    2.32   30  argila  13.875  25.515  1314.0   -3.9   20.4
# 3      P04    0.30    1.50   35  argila  24.850  25.105   855.5   -3.7    9.2
# 4      P05    0.25    1.20   45  argila  24.850  25.255   478.6   -3.1    5.0
#
#     Fz-c2  Mx-c2  My-c2   Fz-c3  Mx-c3  My-c3   h_x (m)   h_y (m)  h_z (m)  \
# 0   511.6  -32.4   -0.4   511.6  -32.4   -0.4  4.091004  3.802110      0.6
# 1   912.1  -65.4    0.1   915.9  -40.0    0.1  3.518413  0.900834      0.6
# 2  1696.4 -214.1    0.8  1698.9 -214.6    0.7  1.511661  2.831424      0.6
# 3   891.9  -60.0    0.6   908.5  -36.9    0.4  3.969535  2.767384      0.6
# 4   496.0  -27.6    0.7   508.0  -27.6    0.7  4.538379  1.872039      0.6
#
#    volume (m3)         x1         y1         x2         y2         x3  \
# 0     9.332668   0.854498  23.353945   4.945502  23.353945   4.945502
# 1     1.901704   6.225794  24.654583   9.744206  24.654583   9.744206
# 2     2.568092  13.119169  24.099288  14.630831  24.099288  14.630831
# 3     6.591137  22.865232  23.721308  26.834768  23.721308  26.834768
# 4     5.097613  22.580811  24.318981  27.119189  24.318981  27.119189
#
#           y3         x4         y4  g sobreposicao  tensao adm. (kPa)  \
# 0  27.156055   0.854498  27.156055        0.000000              200.0
# 1  25.555417   6.225794  25.555417        0.000000              240.0
# 2  26.930712  13.119169  26.930712        0.000000              600.0
# 3  26.488692  22.865232  26.488692        0.676465              700.0
# 4  26.191019  22.580811  26.191019        0.874659              900.0
#
#    tau_sd2 - c1  tau_rd2 - c1  u_rd2 - c1  g_rd2 - c1  k_e - c1  g_ed - c1  \
# 0    407.952024   4339.285714        2.90   -0.905986  1.589768  -0.205116
# 1    599.091787   4339.285714        3.60   -0.861938  1.589768  -0.205116
# 2    599.120664   4339.285714        5.34   -0.861931  1.589768  -0.205116
# 3    578.599034   4339.285714        3.60   -0.866660  1.589768  -0.205116
# 4    401.823088   4339.285714        2.90   -0.907399  1.589768  -0.205116
#
#    tau_rd1 - c1  u_rd1 - c1  kx - c1  ky - c1  w_px - c1  w_py - c1  \
# 0      0.321086    4.784956     0.45      0.8   3.682489   5.021947
# 1      0.321086    5.484956     0.45      0.8   4.300487   6.202433
# 2      0.321086    7.224956     0.45      0.8   5.756984   9.736297
# 3      0.321086    5.484956     0.45      0.8   4.300487   6.202433
# 4      0.321086    4.784956     0.45      0.8   3.682489   5.021947
#
#    tau_sd1 - c1   g_rd1 - c1  tau_sd2 - c2  tau_rd2 - c2  u_rd2 - c2  \
# 0    248.746924   773.705978    429.529235   4339.285714        2.90
# 1    395.842782  1231.826381    616.879227   4339.285714        3.60
# 2    446.151963  1388.511025    773.476632   4339.285714        5.34
# 3    381.704663  1187.794135    603.217391   4339.285714        3.60
# 4    244.548374   760.629871    416.431784   4339.285714        2.90
#
#    g_rd2 - c2  k_e - c2  g_ed - c2  tau_rd1 - c2  u_rd1 - c2  kx - c2  \
# 0   -0.901014  1.589768  -0.205116      0.321086    4.784956     0.45
# 1   -0.857839  1.589768  -0.205116      0.321086    5.484956     0.45
# 2   -0.821750  1.589768  -0.205116      0.321086    7.224956     0.45
# 3   -0.860987  1.589768  -0.205116      0.321086    5.484956     0.45
# 4   -0.904032  1.589768  -0.205116      0.321086    4.784956     0.45
#
#    ky - c2  w_px - c2  w_py - c2  tau_sd1 - c2   g_rd1 - c2  tau_sd2 - c3  \
# 0      0.8   3.682489   5.021947    250.528037   779.253137    429.529235
# 1      0.8   4.300487   6.202433    388.252174  1208.185931    619.449275
# 2      0.8   5.756984   9.736297    531.093531  1653.055968    774.616512
# 3      0.8   4.300487   6.202433    380.818155  1185.033166    614.444444
# 4      0.8   3.682489   5.021947    244.444908   760.307633    426.506747
#
#    tau_rd2 - c3  u_rd2 - c3  g_rd2 - c3  k_e - c3  g_ed - c3  tau_rd1 - c3  \
# 0   4339.285714        2.90   -0.901014  1.589768  -0.205116      0.321086
# 1   4339.285714        3.60   -0.857246  1.589768  -0.205116      0.321086
# 2   4339.285714        5.34   -0.821488  1.589768  -0.205116      0.321086
# 3   4339.285714        3.60   -0.858400  1.589768  -0.205116      0.321086
# 4   4339.285714        2.90   -0.901710  1.589768  -0.205116      0.321086
#
#    u_rd1 - c3  kx - c3  ky - c3  w_px - c3  w_py - c3  tau_sd1 - c3  \
# 0    4.784956     0.45      0.8   3.682489   5.021947    250.528037
# 1    5.484956     0.45      0.8   4.300487   6.202433    396.410261
# 2    7.224956     0.45      0.8   5.756984   9.736297    531.820857
# 3    5.484956     0.45      0.8   4.300487   6.202433    394.009399
# 4    4.784956     0.45      0.8   3.682489   5.021947    250.551003
#
#     g_rd1 - c3  g punção secao C  g escala punção  g punção secao Clinha  \
# 0   779.253137         -0.901014        -0.205116             779.253137
# 1  1233.593758         -0.857246        -0.205116            1233.593758
# 2  1655.321177         -0.821488        -0.205116            1655.321177
# 3  1226.116429         -0.858400        -0.205116            1226.116429
# 4   779.324664         -0.901710        -0.205116             779.324664
#
#    tensao max. (kPa) - c1  tensao min. (kPa) - c1  g tensao max. - c1  \
# 0               33.267054               32.334126           -0.783764
# 1              314.314126              272.584660            0.702535
# 2              336.750561              307.945883           -0.270374
# 3               84.212291               79.330063           -0.843606
# 4               61.635895               56.661832           -0.910970
#
#    g tensao min. - c1  g tensao - c1  tensao max. (kPa) - c2  \
# 0           -0.789828      -0.783764               37.785829
# 1            0.476500       0.702535              339.329804
# 2           -0.332784      -0.270374              625.043724
# 3           -0.852673      -0.843606               94.043218
# 4           -0.918155      -0.910970               66.086107
#
#    tensao min. (kPa) - c2  g tensao max. - c2  g tensao min. - c2  \
# 0               31.285098           -0.754392           -0.796647
# 1              264.994403            0.838036            0.435386
# 2              207.272142            0.354261           -0.550910
# 3               76.457571           -0.825348           -0.858007
# 4               56.512458           -0.904542           -0.918371
#
#    g tensao - c2  tensao max. (kPa) - c3  tensao min. (kPa) - c3  \
# 0      -0.754392               37.785829               31.285098
# 1       0.838036              326.239209              280.602740
# 2       0.354261              626.091886              207.450571
# 3      -0.825348               92.251081               81.423060
# 4      -0.904542               67.569154               57.995505
#
#    g tensao max. - c3  g tensao min. - c3  g tensao - c3  g tensao  \
# 0           -0.754392           -0.796647      -0.754392 -0.754392
# 1            0.767129            0.519932       0.767129  0.838036
# 2            0.356532           -0.550524       0.356532  0.356532
# 3           -0.828677           -0.848786      -0.828677 -0.825348
# 4           -0.902400           -0.916229      -0.902400 -0.902400
#
#    g geometria x  g geometria y  g geometria  volume final (m3)
# 0      -3.941004      -2.702110    -2.702110       7.792531e+08
# 1      -3.318413       0.499166     0.499166       1.234931e+09
# 2      -1.261661      -0.611424    -0.611424       1.655678e+09
# 3      -3.769535      -1.367384    -1.367384       1.226793e+09
# 4      -4.388379      -0.772039    -0.772039       7.801993e+08
