# %% [markdown]
# # Bibliotecas

# %%
from fundacao import *
import pandas as pd
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Checagem fundação 16

# %%
x = [3, 3.1, 1.0]

# %%
df = pd.read_excel(r"/home/wmpjrufg/Documents/fundaIA/assets/sapata_16.xlsx") # Prof. Wanderlei
n_comb = 3
f_ck = 25000
cob_m = 0.04
df
# x = {'h_x (m)': 3.0, 'h_y (m)': 3.1, 'h_z (m)': 1.0}
# x = pd.DataFrame([x])
# x = [3, 3.1, 1.0, 4, 4.1, 1.2, 5, 5.1, 1.3]
# x_arr = np.asarray(x).reshape(3, 3)
# print(x, '\n', x_arr)
# df_aux_aux = pd.DataFrame(x_arr, columns=["h_x (m)", "h_y (m)", "h_z (m)"])
# print(df_aux_aux)
# Out:
#   Elemento  ap (m)  bp (m)  spt    solo  xg (m)  yg (m)  Fz-c1  Mx-c1  My-c1  \
# 0      P16    0.25     1.2   43  argila   27.75  18.065  377.3   -1.9    4.4
#
#    Fz-c2  Mx-c2  My-c2  Fz-c3  Mx-c3  My-c3
# 0  259.2  -27.8    0.1  383.8   27.7    0.2

# %%
args = [df, n_comb, f_ck, cob_m]
of, df_res = obj_teste(x, args)
df_res
# Out:
#   Elemento  ap (m)  bp (m)  spt    solo  xg (m)  yg (m)  Fz-c1  Mx-c1  My-c1  \
# 0      P16    0.25     1.2   43  argila   27.75  18.065  377.3   -1.9    4.4
#
#    Fz-c2  Mx-c2  My-c2  Fz-c3  Mx-c3  My-c3  h_x (m)  h_y (m)  h_z (m)  \
# 0  259.2  -27.8    0.1  383.8   27.7    0.2      3.0      3.1      1.0
#
#    volume (m3)     x1      y1     x2      y2     x3      y3     x4      y4  \
# 0          9.3  26.25  16.515  29.25  16.515  29.25  19.615  26.25  19.615
#
#    g sobreposicao  tensao adm. (kPa)  tau_sd2 - c1  tau_rd2 - c1  u_rd2 - c1  \
# 0             0.0              860.0    189.734195   4339.285714         2.9
#
#    g_rd2 - c1  tau_sd2 - c2  tau_rd2 - c2  u_rd2 - c2  g_rd2 - c2  \
# 0   -0.956275    130.344828   4339.285714         2.9   -0.969962
#
#    tau_sd2 - c3  tau_rd2 - c3  u_rd2 - c3  g_rd2 - c3  g punção secao C  \
# 0    193.002874   4339.285714         2.9   -0.955522         -0.955522
#
#    tensao max. (kPa) - c1  tensao min. (kPa) - c1  g tensao max. - c1  \
# 0               43.988918               41.207856           -0.933505
#
#    g tensao min. - c1  g tensao - c1  tensao max. (kPa) - c2  \
# 0           -0.937709      -0.933505               35.563788
#
#    tensao min. (kPa) - c2  g tensao max. - c2  g tensao min. - c2  \
# 0               22.965245           -0.946241           -0.965285
#
#    g tensao - c2  tensao max. (kPa) - c3  tensao min. (kPa) - c3  \
# 0      -0.946241               49.630801               37.033715
#
#    g tensao max. - c3  g tensao min. - c3  g tensao - c3  g tensao  \
# 0           -0.924977           -0.944019      -0.924977 -0.924977
#
#    g geometria x  g geometria y  g geometria  volume final (m3)
# 0          -2.85           -2.0         -2.0                9.3

# %%
df_res.columns
# Out:
# Index(['Elemento', 'ap (m)', 'bp (m)', 'spt', 'solo', 'xg (m)', 'yg (m)',
#        'Fz-c1', 'Mx-c1', 'My-c1', 'Fz-c2', 'Mx-c2', 'My-c2', 'Fz-c3', 'Mx-c3',
#        'My-c3', 'h_x (m)', 'h_y (m)', 'h_z (m)', 'volume (m3)', 'x1', 'y1',
#        'x2', 'y2', 'x3', 'y3', 'x4', 'y4', 'g sobreposicao',
#        'tensao adm. (kPa)', 'tau_sd2 - c1', 'tau_rd2 - c1', 'u_rd2 - c1',
#        'g_rd2 - c1', 'tau_sd2 - c2', 'tau_rd2 - c2', 'u_rd2 - c2',
#        'g_rd2 - c2', 'tau_sd2 - c3', 'tau_rd2 - c3', 'u_rd2 - c3',
#        'g_rd2 - c3', 'g punção secao C', 'tensao max. (kPa) - c1',
#        'tensao min. (kPa) - c1', 'g tensao max. - c1', 'g tensao min. - c1',
#        'g tensao - c1', 'tensao max. (kPa) - c2', 'tensao min. (kPa) - c2',
#        'g tensao max. - c2', 'g tensao min. - c2', 'g tensao - c2',
#        'tensao max. (kPa) - c3', 'tensao min. (kPa) - c3',
#        'g tensao max. - c3', 'g tensao min. - c3', 'g tensao - c3', 'g tensao',
#        'g geometria x', 'g geometria y', 'g geometria', 'volume final (m3)'],
#       dtype='object')

# %%
df_gtensao = df_res[['tensao max. (kPa) - c1',
       'tensao min. (kPa) - c1', 'g tensao max. - c1', 'g tensao min. - c1',
       'g tensao - c1', 'tensao max. (kPa) - c2', 'tensao min. (kPa) - c2',
       'g tensao max. - c2', 'g tensao min. - c2', 'g tensao - c2',
       'tensao max. (kPa) - c3', 'tensao min. (kPa) - c3',
       'g tensao max. - c3', 'g tensao min. - c3', 'g tensao - c3', 'g tensao',]]
print(df_gtensao.to_latex(
    column_format=''.join(['c' for _ in range(len(df_gtensao.columns) + 1)]),
    float_format="%.2f",
    caption='Resultados das tensões e verificações',
    label='tab:tensoes_s16',
    index=False,
    position='htbp'
))
# Out:
# \begin{table}[htbp]
# \caption{Resultados das tensões e verificações}
# \label{tab:tensoes_s16}
# \begin{tabular}{ccccccccccccccccc}
# \toprule
# tensao max. (kPa) - c1 & tensao min. (kPa) - c1 & g tensao max. - c1 & g tensao min. - c1 & g tensao - c1 & tensao max. (kPa) - c2 & tensao min. (kPa) - c2 & g tensao max. - c2 & g tensao min. - c2 & g tensao - c2 & tensao max. (kPa) - c3 & tensao min. (kPa) - c3 & g tensao max. - c3 & g tensao min. - c3 & g tensao - c3 & g tensao \\
# \midrule
# 43.99 & 41.21 & -0.93 & -0.94 & -0.93 & 35.56 & 22.97 & -0.95 & -0.97 & -0.95 & 49.63 & 37.03 & -0.92 & -0.94 & -0.92 & -0.92 \\
# \bottomrule
# \end{tabular}
# \end{table}
