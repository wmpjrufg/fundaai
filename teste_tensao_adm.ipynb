# %%
import numpy as np
import pandas as pd
from foundation import *

# %%
df = pd.read_excel(r'assets\template_5_fundacoes_3_combinacoes.xlsx')


df['tensao adm. (kPa)'] = df.apply(
    lambda row: tensao_adm_solo(row['solo'], row['spt']),
    axis=1
)

print(df)
# Out:
#   Elemento  ap (m)  bp (m)  spt    solo  xg (m)  yg (m)   Fz-c1  Mx-c1  My-c1  \
# 0      P01    0.25    1.20   10  argila   2.900  25.255   485.9   -0.3    4.1
# 1      P02    0.30    1.50   12  argila   7.985  25.105   885.8   -1.0    9.2
# 2      P03    0.35    2.32   30  argila  13.875  25.515  1314.0   -3.9   20.4
# 3      P04    0.30    1.50   35  argila  24.850  25.105   855.5   -3.7    9.2
# 4      P05    0.25    1.20   45  argila  24.850  25.255   478.6   -3.1    5.0
#
#     Fz-c2  Mx-c2  My-c2   Fz-c3  Mx-c3  My-c3  tensao adm. (kPa)
# 0   511.6  -32.4   -0.4   511.6  -32.4   -0.4              200.0
# 1   912.1  -65.4    0.1   915.9  -40.0    0.1              240.0
# 2  1696.4 -214.1    0.8  1698.9 -214.6    0.7              600.0
# 3   891.9  -60.0    0.6   908.5  -36.9    0.4              700.0
# 4   496.0  -27.6    0.7   508.0  -27.6    0.7              900.0
