# %% [markdown]
# # Import library

# %%
import pandas as pd
from my_example import obj_ic_fundacoes, tensao_adm_solo
from metapy_toolbox import metaheuristic_optimizer

# %% [markdown]
# # Setup and call function

# %%
df_aux = pd.read_excel('input.xlsx')
df = tensao_adm_solo(df_aux)
df
# Out:
#   Elemento  Grupo  Fz,max (kN)  Fz,min (kN)  My,max (kN.m)  My,min (kN.m)  \
# 0       P1      1          750          720            325           -200
# 1       P2      1          750          720            325           -200
# 2       P3      1          750          720            325           -200
# 3       P4      1          750          720            325           -200
# 4       P5      1          750          720            325           -200
# 5       P6      1          750          720            325           -200
#
#    Mx,max (kN.m)  Mx,min (kN.m)  spt    solo  sigma_adm (kPa)
# 0            300           -300   10  argila            200.0
# 1            300           -300   10  argila            200.0
# 2            300           -300   10  argila            200.0
# 3            300           -300   10  argila            200.0
# 4            300           -300   10  argila            200.0
# 5            300           -300   10  argila            200.0

# %%
dim_a = []
dim_b = []

for i, row in df.iterrows():
        # Recolhendo os dados do pilar
        f_zmax = row['Fz,max (kN)']
        f_zmin = row['Fz,min (kN)']
        m_xmax = row['Mx,max (kN.m)']
        m_xmin = row['Mx,min (kN.m)']
        m_ymax = row['My,max (kN.m)']
        m_ymin = row['My,min (kN.m)']
        sigma_lim_solo = row['sigma_adm (kPa)']
        dados_fundacao = { 
                                'Fz,max (kN)': f_zmax,
                                'Fz,min (kN)': f_zmin,
                                'Mx,max (kN.m)': m_xmax,
                                'Mx,min (kN.m)': m_xmin,
                                'My,max (kN.m)': m_ymax,
                                'My,min (kN.m)': m_ymin,
                                'sigma_adm (kPa)': sigma_lim_solo,
                         }
        
        # Otimização
        algorithm_setup = {   
                'number of iterations': 100,
                'number of population': 10,
                'number of dimensions': 2,
                'x pop lower limit': [0.30, 0.30], # 0.60
                'x pop upper limit': [2.25, 2.25],
                'none variable': dados_fundacao,
                'objective function': obj_ic_fundacoes,
                'algorithm parameters': {
                                        'selection': {'type': 'roulette'},
                                        'crossover': {'crossover rate (%)': 82, 'type':'linear'},
                                        'mutation': {'mutation rate (%)': 12, 'type': 'hill climbing', 'cov (%)': 15, 'pdf': 'gaussian'},
                                        }
                }
        n_rep = 10
        general_setup = {   
                'number of repetitions': n_rep,
                'type code': 'real code',
                'initial pop. seed': [None] * n_rep,
                'algorithm': 'genetic_algorithm_01',
                }
        df_all_reps, df_resume_all_reps, reports, status = metaheuristic_optimizer(algorithm_setup, general_setup)
        df_novo = df_resume_all_reps[status]
        dimensoes_sapata_a = list(df_novo['X_0_BEST'])[-1]
        dimensoes_sapata_b = list(df_novo['X_1_BEST'])[-1]
        dim_a.append(dimensoes_sapata_a)
        dim_b.append(dimensoes_sapata_b)

# Atribuição da dimensão otimizada
df['dimensão a (m)'] = dim_a
df['dimensão b (m)'] = dim_b
# Out:
#  Optimization results:
#
#  - Best repetition id:    0
#  - Best of:               2.6320990692e+07
#  - Design variables:      [2.25, 2.25]
#  - Process time (s):      3.383716
#  - Best process time (s): 0.007998
#
#  Optimization results:
#
#  - Best repetition id:    0
#  - Best of:               2.6320990692e+07
#  - Design variables:      [2.25, 2.25]
#  - Process time (s):      3.546902
#  - Best process time (s): 0.006035
#
#  Optimization results:
#
#  - Best repetition id:    0
#  - Best of:               2.6320990692e+07
#  - Design variables:      [2.25, 2.25]
#  - Process time (s):      3.988904
#  - Best process time (s): 0.005170
#
#  Optimization results:
#
#  - Best repetition id:    0
#  - Best of:               2.6320990692e+07
#  - Design variables:      [2.25, 2.25]
#  - Process time (s):      3.901010
#  - Best process time (s): 0.005940
#
#  Optimization results:
#
#  - Best repetition id:    0
#  - Best of:               2.6320990692e+07
#  - Design variables:      [2.25, 2.25]
#  - Process time (s):      4.752939
#  - Best process time (s): 0.005146
#
#  Optimization results:
#
#  - Best repetition id:    0
#  - Best of:               2.6320990692e+07
#  - Design variables:      [2.25, 2.25]
#  - Process time (s):      3.903154
#  - Best process time (s): 0.006001

# %%
df
# Out:
#   Elemento  Grupo  Fz,max (kN)  Fz,min (kN)  My,max (kN.m)  My,min (kN.m)  \
# 0       P1      1          750          720            325           -200
# 1       P2      1          750          720            325           -200
# 2       P3      1          750          720            325           -200
# 3       P4      1          750          720            325           -200
# 4       P5      1          750          720            325           -200
# 5       P6      1          750          720            325           -200
#
#    Mx,max (kN.m)  Mx,min (kN.m)  spt    solo  sigma_adm (kPa)  dimensão a (m)  \
# 0            300           -300   10  argila            200.0            2.25
# 1            300           -300   10  argila            200.0            2.25
# 2            300           -300   10  argila            200.0            2.25
# 3            300           -300   10  argila            200.0            2.25
# 4            300           -300   10  argila            200.0            2.25
# 5            300           -300   10  argila            200.0            2.25
#
#    dimensão b (m)
# 0            2.25
# 1            2.25
# 2            2.25
# 3            2.25
# 4            2.25
# 5            2.25

# %%
df = pd.read_excel('input.xlsx')
x = [1, 1]
none_variable = {'Fz,max (kN)': 750,
                    'Fz,min (kN)': 720,
                    'Mx,max (kN.m)': 325,
                    'Mx,min (kN.m)': -200,
                    'My,max (kN.m)': 300,
                    'My,min (kN.m)': -300,
                    'sigma_adm (kPa)': 333.33}
print(obj_ic_fundacoes(x, none_variable))
# Out:
# 250977710.37709776
